# %%
import pandas as pd
import altair as alt
import numpy as np
import yfinance as yf
from IPython.display import display
alt.data_transformers.disable_max_rows()
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
a= -5
b = 6
c = a+b
print(c)
import altair
# Out:
# 1

# %%
abs(a)
# Out:
# 5

# %%
AAPL = yf.download("AAPL", start = "2010-01-01",end ="2023-01-01")
AAPL.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2010-01-04  7.622500  7.660714  7.585000  7.643214   6.478999  493729600
# 2010-01-05  7.664286  7.699643  7.616071  7.656429   6.490201  601904800
# 2010-01-06  7.656429  7.686786  7.526786  7.534643   6.386963  552160000
# 2010-01-07  7.562500  7.571429  7.466071  7.520714   6.375156  477131200
# 2010-01-08  7.510714  7.571429  7.466429  7.570714   6.417541  447610800

# %% [markdown]
# # Reading the stocks

# %%
ticker=["SPY","MSFT","AAPL","TSLA"]
stocks = yf.download(ticker, start = "2022-01-01",end ="2023-11-16")
stocks.head()
display(stocks.tail())
display(stocks.info())
stocks.to_csv("sushmit_stocksYT.csv")
stocks = pd.read_csv("sushmit_stocksYT.csv")
display(stocks.head())
# Out:
# [*********************100%%**********************]  4 of 4 completed
#              Adj Close                                           Close  \
#                   AAPL        MSFT         SPY        TSLA        AAPL
# Date
# 2023-11-09  182.169998  359.959412  433.839996  209.979996  182.410004
# 2023-11-10  186.399994  368.921234  440.609985  214.649994  186.399994
# 2023-11-13  184.800003  365.937256  440.190002  223.710007  184.800003
# 2023-11-14  187.440002  369.519989  448.730011  237.410004  187.440002
# 2023-11-15  188.009995  369.670013  449.679993  242.839996  188.009995
#
#                                                       High              ...  \
#                   MSFT         SPY        TSLA        AAPL        MSFT  ...
# Date                                                                    ...
# 2023-11-09  360.690002  433.839996  209.979996  184.119995  364.790009  ...
# 2023-11-10  369.670013  440.609985  214.649994  186.570007  370.100006  ...
# ...

# %% [markdown]
# ## Playing with index

# %%
stocks = pd.read_csv("sushmit_stocksYT.csv",header=[0,1],index_col=[0],parse_dates =[0])
display(stocks.info())
display(stocks.head())
#convert mult index to one tuple
stocks.columns=stocks.columns.to_flat_index()
display(stocks.columns)
display(stocks.head())
stocks.columns=pd.MultiIndex.from_tuples(stocks.columns)
display(stocks.head())
display(stocks.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 471 entries, 2022-01-03 to 2023-11-15
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, AAPL)  471 non-null    float64
#  1   (Adj Close, MSFT)  471 non-null    float64
#  2   (Adj Close, SPY)   471 non-null    float64
#  3   (Adj Close, TSLA)  471 non-null    float64
#  4   (Close, AAPL)      471 non-null    float64
#  5   (Close, MSFT)      471 non-null    float64
#  6   (Close, SPY)       471 non-null    float64
#  7   (Close, TSLA)      471 non-null    float64
#  8   (High, AAPL)       471 non-null    float64
#  9   (High, MSFT)       471 non-null    float64
#  10  (High, SPY)        471 non-null    float64
#  11  (High, TSLA)       471 non-null    float64
#  12  (Low, AAPL)        471 non-null    float64
#  13  (Low, MSFT)        471 non-null    float64
#  14  (Low, SPY)         471 non-null    float64
# ...

# %% [markdown]
# ## Plotting the close price

# %%
close = stocks.loc[:,'Close'].copy()
close_long_form = close.reset_index().melt('Date',var_name = 'company',value_name = 'price').copy()

alt.Chart(close_long_form).mark_line().encode(x= 'Date',y = 'price', color = 'company').properties(
    width=1000,
    height=600,
    title = 'Closing Price'
)
# Out:
# alt.Chart(...)

# %% [markdown]
# # Plot the normalized price

# %%
normclose=close.div(close.iloc[0]).mul(100)
normclose.plot(figsize=(15,8),fontsize=12)
plt.legend(fontsize=12)
plt.show()
